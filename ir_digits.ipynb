
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-def15e8e2bc3> in <module>
#       3
#       4 #model = onnx.load('lr_digits.onnx')
# ----> 5 model = onnx.load('minst.onnx')
#       6 print(onnx.helper.printable_graph(model.graph))
#
# ~\Anaconda3\lib\site-packages\onnx\__init__.py in load_model(f, format, load_external_data)
#     111     Loaded in-memory ModelProto
#     112     '''
# --> 113     s = _load_bytes(f)
#     114     model = load_model_from_string(s, format=format)
#     115
#
# ~\Anaconda3\lib\site-packages\onnx\__init__.py in _load_bytes(f)
#      27         s = cast(IO[bytes], f).read()
#      28     else:
# ---> 29         with open(cast(Text, f), 'rb') as readable:
#      30             s = readable.read()
#      31     return s
#
# FileNotFoundError: [Errno 2] No such file or directory: 'minst.onnx'

# %%
import onnx
import onnx.helper

#model = onnx.load('lr_digits.onnx')
model = onnx.load('mnist.onnx')
print(onnx.helper.printable_graph(model.graph))
# Out:
# graph CNTKGraph (
#   %Input3[FLOAT, 1x1x28x28]
# ) initializers (
#   %Parameter5[FLOAT, 8x1x5x5]
#   %Parameter6[FLOAT, 8x1x1]
#   %Parameter87[FLOAT, 16x8x5x5]
#   %Parameter88[FLOAT, 16x1x1]
#   %Pooling160_Output_0_reshape0_shape[INT64, 2]
#   %Parameter193[FLOAT, 16x4x4x10]
#   %Parameter193_reshape1_shape[INT64, 2]
#   %Parameter194[FLOAT, 1x10]
# ) {
#   %Parameter193_reshape1 = Reshape(%Parameter193, %Parameter193_reshape1_shape)
#   %Convolution28_Output_0 = Conv[auto_pad = 'SAME_UPPER', dilations = [1, 1], group = 1, kernel_shape = [5, 5], strides = [1, 1]](%Input3, %Parameter5)
#   %Plus30_Output_0 = Add(%Convolution28_Output_0, %Parameter6)
#   %ReLU32_Output_0 = Relu(%Plus30_Output_0)
#   %Pooling66_Output_0 = MaxPool[auto_pad = 'NOTSET', kernel_shape = [2, 2], pads = [0, 0, 0, 0], strides = [2, 2]](%ReLU32_Output_0)
#   %Convolution110_Output_0 = Conv[auto_pad = 'SAME_UPPER', dilations = [1, 1], group = 1, kernel_shape = [5, 5], strides = [1, 1]](%Pooling66_Output_0, %Parameter87)
#   %Plus112_Output_0 = Add(%Convolution110_Output_0, %Parameter88)
#   %ReLU114_Output_0 = Relu(%Plus112_Output_0)
#   %Pooling160_Output_0 = MaxPool[auto_pad = 'NOTSET', kernel_shape = [3, 3], pads = [0, 0, 0, 0], strides = [3, 3]](%ReLU114_Output_0)
#   %Pooling160_Output_0_reshape0 = Reshape(%Pooling160_Output_0, %Pooling160_Output_0_reshape0_shape)
#   %Times212_Output_0 = MatMul(%Pooling160_Output_0_reshape0, %Parameter193_reshape1)
#   %Plus214_Output_0 = Add(%Times212_Output_0, %Parameter194)
#   return %Plus214_Output_0
# }
